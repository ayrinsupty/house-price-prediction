# %%
# Step 1: Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset
df = pd.read_csv('../data/raw/train.csv')

# %%
# Set styles
sns.set(style="whitegrid")
plt.style.use("dark_background")

# %%
# Step 2: Correlation heatmap
plt.figure(figsize=(14, 10))
numeric_df = df.select_dtypes(include=[np.number])  # Only numeric columns
corr = numeric_df.corr()
sns.heatmap(corr, cmap="coolwarm", annot=False, linewidths=0.5)
plt.title('Correlation Heatmap of Numeric Features')
plt.show()

# %%
# Step 3: Distribution of SalePrice
plt.figure(figsize=(8, 5))
sns.histplot(df['SalePrice'], kde=True, color="skyblue")
plt.title("Distribution of SalePrice")
plt.xlabel("SalePrice")
plt.ylabel("Frequency")
plt.show()

# %%
# Step 4: Scatterplots for numeric relationships
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
sns.scatterplot(data=df, x="GrLivArea", y="SalePrice", ax=axes[0])
axes[0].set_title("SalePrice vs GrLivArea")

sns.scatterplot(data=df, x="TotalBsmtSF", y="SalePrice", ax=axes[1])
axes[1].set_title("TotalBsmtSF vs SalePrice")
plt.tight_layout()
plt.show()

# %%
# Step 5: Boxplots for categorical features
plt.figure(figsize=(12, 6))
sns.boxplot(x='OverallQual', y='SalePrice', data=df)
plt.title("SalePrice vs Overall Quality")
plt.show()

plt.figure(figsize=(16, 6))
top_neighborhoods = df['Neighborhood'].value_counts().index[:10]
sns.boxplot(x='Neighborhood', y='SalePrice', data=df[df['Neighborhood'].isin(top_neighborhoods)])
plt.title("SalePrice vs Top 10 Neighborhoods")
plt.xticks(rotation=45) 

plt.show()
